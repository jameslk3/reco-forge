# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movies/movies_metadata.csv')
df.head()
# Out:
# /var/folders/h9/x2v2_krn40q63ccf8mytsdb80000gn/T/ipykernel_7703/1724636363.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies/movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
df = df.filter(['id', 'title', 'genres', 'vote_average', "vote_count"])
df = df[df["vote_count"] != 0.0] 
df["vote_score"] = df['vote_average'] * np.log(df['vote_count'])
df.head()
# Out:
#         id                        title  \
# 0    862.0                    Toy Story
# 1   8844.0                      Jumanji
# 2  15602.0             Grumpier Old Men
# 3  31357.0            Waiting to Exhale
# 4  11862.0  Father of the Bride Part II
#
#                                               genres  vote_average  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...           7.7
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           6.9
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...           6.5
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.1
# 4                     [{'id': 35, 'name': 'Comedy'}]           5.7
#
#    vote_count  vote_score
# 0      5415.0   66.196347
# 1      2413.0   53.741520
# 2        92.0   29.391626
# 3        34.0   21.510799
# 4       173.0   29.373762

# %%
df2 = pd.read_csv('movies/keywords.csv')
df2.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df['id'] = pd.to_numeric(df['id'], errors='coerce', downcast='integer')
merged_df = pd.merge(df, df2[['id', 'keywords']], on='id', how='left')
len(merged_df)
# Out:
# 43477

# %%
merged_df = merged_df.loc[(merged_df["genres"] != "[]") & (merged_df["keywords"] != "[]")]

# %%
print(merged_df[merged_df["id"] == 9087])
# Out:
#         id                   title  \
# 10  9087.0  The American President
#
#                                                genres  vote_average  \
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.5
#
#     vote_count  vote_score                                           keywords
# 10       199.0   34.406481  [{'id': 833, 'name': 'white house'}, {'id': 84...

# %%
merged_df.sort_values(by='vote_score', inplace=True, ascending=False)
merged_df.head(60)
# Out:
#              id                                              title  \
# 12281     155.0                                    The Dark Knight
# 15202   27205.0                                          Inception
# 307       278.0                           The Shawshank Redemption
# 2750      550.0                                         Fight Club
# 22159  157336.0                                       Interstellar
# 285       680.0                                       Pulp Fiction
# 803       238.0                                      The Godfather
# 344        13.0                                       Forrest Gump
# 6837      122.0      The Lord of the Rings: The Return of the King
# 22958  118340.0                            Guardians of the Galaxy
# 4733      120.0  The Lord of the Rings: The Fellowship of the Ring
# 19523   68718.0                                   Django Unchained
# 2373      603.0                                         The Matrix
# 5668      121.0              The Lord of the Rings: The Two Towers
# 250        11.0                                          Star Wars
# 1107     1891.0                            The Empire Strikes Back
# 18068   77338.0                                   The Intouchables
# 46        807.0                                              Se7en
# 1178      105.0                                 Back to the Future
# 512       424.0                                   Schindler's List
# 21470  106646.0                            The Wolf of Wall Street
# 28972  150540.0                                         Inside Out
# 22888  244786.0                                           Whiplash
# 17448   24428.0                                       The Avengers
# 13381   16869.0                               Inglourious Basterds
# 23970  205596.0                                 The Imitation Game
# 17863   49026.0                              The Dark Knight Rises
# 25544  293660.0                                           Deadpool
# 13495   14160.0                                                 Up
# 352      8587.0                                      The Lion King
# 17081   12445.0       Harry Potter and the Deathly Hallows: Part 2
# 5345      129.0                                      Spirited Away
# 22889  210577.0                                          Gone Girl
# 282       101.0                             Leon: The Professional
# 14566   11324.0                                     Shutter Island
# 12502   10681.0                                             WALL·E
# 2935      497.0                                     The Green Mile
# 573       274.0                           The Silence of the Lambs
# 23591  177572.0                                         Big Hero 6
# 3344       98.0                                          Gladiator
# 2129      637.0                                  Life Is Beautiful
# 28723  286217.0                                        The Martian
# 14303   19995.0                                             Avatar
# 22125  120467.0                           The Grand Budapest Hotel
# 1131      240.0                             The Godfather: Part II
# 1842      857.0                                Saving Private Ryan
# 3978       77.0                                            Memento
# 25536  140607.0                       Star Wars: The Force Awakens
# 12387    1726.0                                           Iron Man
# 11163    1124.0                                       The Prestige
# 1575      597.0                                            Titanic
# 7553      673.0           Harry Potter and the Prisoner of Azkaban
# 25534   76341.0                                 Mad Max: Fury Road
# 1166      694.0                                        The Shining
# 9935      272.0                                      Batman Begins
# 1120     1892.0                                 Return of the Jedi
# 39340  313369.0                                         La La Land
# 1019      500.0                                     Reservoir Dogs
# 6238       22.0  Pirates of the Caribbean: The Curse of the Bla...
# 4636      671.0           Harry Potter and the Philosopher's Stone
#
#                                                   genres  vote_average  \
# 12281  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...           8.3
# 15202  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...           8.1
# 307    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           8.5
# 2750                       [{'id': 18, 'name': 'Drama'}]           8.3
# 22159  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...           8.1
# 285    [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...           8.3
# 803    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           8.5
# 344    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           8.2
# 6837   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           8.1
# 22958  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...           7.9
# 4733   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           8.0
# 19523  [{'id': 18, 'name': 'Drama'}, {'id': 37, 'name...           7.8
# 2373   [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...           7.9
# 5668   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           8.0
# 250    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...           8.1
# 1107   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...           8.2
# 18068  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...           8.2
# 46     [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...           8.1
# 1178   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...           8.0
# 512    [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...           8.3
# 21470  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...           7.9
# 28972  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...           7.9
# 22888                      [{'id': 18, 'name': 'Drama'}]           8.3
# 17448  [{'id': 878, 'name': 'Science Fiction'}, {'id'...           7.4
# 13381  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...           7.9
# 23970  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...           8.0
# 17863  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...           7.6
# 25544  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           7.4
# 13495  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...           7.8
# 352    [{'id': 10751, 'name': 'Family'}, {'id': 16, '...           8.0
# 17081  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...           7.9
# 5345   [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...           8.3
# 22889  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...           7.9
# 282    [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...           8.2
# 14566  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...           7.8
# 12502  [{'id': 16, 'name': 'Animation'}, {'id': 10751...           7.8
# 2935   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...           8.2
# 573    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...           8.1
# 23591  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...           7.8
# 3344   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...           7.9
# 2129   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           8.3
# 28723  [{'id': 18, 'name': 'Drama'}, {'id': 12, 'name...           7.6
# 14303  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           7.2
# 22125  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           8.0
# 1131   [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           8.3
# 1842   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...           7.9
# 3978   [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...           8.1
# 25536  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           7.5
# 12387  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...           7.4
# 11163  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...           8.0
# 1575   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...           7.5
# 7553   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           7.7
# 25534  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           7.3
# 1166   [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...           8.1
# 9935   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...           7.5
# 1120   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...           7.9
# 39340  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           7.9
# 1019   [{'id': 80, 'name': 'Crime'}, {'id': 53, 'name...           8.1
# 6238   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           7.5
# 4636   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           7.5
#
#        vote_count  vote_score  \
# 12281     12269.0   78.143098
# 15202     14075.0   77.372459
# 307        8358.0   76.763283
# 2750       9678.0   76.174168
# 22159     11187.0   75.512312
# 285        8670.0   75.261280
# 803        6024.0   73.979808
# 344        8147.0   73.844321
# 6837       8226.0   73.021947
# 22958     10014.0   72.772741
# 4733       8892.0   72.743258
# 19523     10297.0   72.068941
# 2373       9079.0   71.998383
# 5668       7641.0   71.530270
# 250        6778.0   71.453643
# 1107       5998.0   71.333287
# 18068      5410.0   70.487236
# 46         5915.0   70.350499
# 1178       6239.0   69.908602
# 512        4436.0   69.699319
# 21470      6768.0   69.677691
# 28972      6737.0   69.641423
# 22888      4376.0   69.586290
# 17448     12000.0   69.505698
# 13381      6598.0   69.476723
# 23970      5895.0   69.454879
# 17863      9263.0   69.416753
# 25544     11444.0   69.154634
# 13495      7048.0   69.111894
# 352        5520.0   68.929065
# 17081      6141.0   68.909669
# 5345       3968.0   68.773945
# 22889      6023.0   68.756392
# 282        4293.0   68.590877
# 14566      6559.0   68.551029
# 12502      6439.0   68.407003
# 2935       4166.0   68.344635
# 573        4549.0   68.223568
# 23591      6289.0   68.223147
# 3344       5566.0   68.133012
# 2129       3643.0   68.064671
# 28723      7442.0   67.753201
# 14303     12114.0   67.695243
# 22125      4644.0   67.546651
# 1131       3418.0   67.535530
# 1842       5148.0   67.516272
# 3978       4168.0   67.515052
# 25536      7993.0   67.397411
# 12387      8951.0   67.336452
# 11163      4510.0   67.312419
# 1575       7770.0   67.185191
# 7553       6037.0   67.033601
# 25534      9629.0   66.959503
# 1166       3890.0   66.955932
# 9935       7511.0   66.930929
# 1120       4763.0   66.902201
# 39340      4745.0   66.872289
# 1019       3821.0   66.810966
# 6238       7191.0   66.604391
# 4636       7188.0   66.601262
#
#                                                 keywords
# 12281  [{'id': 849, 'name': 'dc comics'}, {'id': 853,...
# 15202  [{'id': 1014, 'name': 'loss of lover'}, {'id':...
# 307    [{'id': 378, 'name': 'prison'}, {'id': 417, 'n...
# 2750   [{'id': 825, 'name': 'support group'}, {'id': ...
# 22159  [{'id': 83, 'name': 'saving the world'}, {'id'...
# 285    [{'id': 396, 'name': 'transporter'}, {'id': 14...
# 803    [{'id': 131, 'name': 'italy'}, {'id': 699, 'na...
# 344    [{'id': 422, 'name': 'vietnam veteran'}, {'id'...
# 6837   [{'id': 603, 'name': 'elves'}, {'id': 606, 'na...
# 22958  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 4733   [{'id': 603, 'name': 'elves'}, {'id': 604, 'na...
# 19523  [{'id': 801, 'name': 'bounty hunter'}, {'id': ...
# 2373   [{'id': 83, 'name': 'saving the world'}, {'id'...
# 5668   [{'id': 603, 'name': 'elves'}, {'id': 606, 'na...
# 250    [{'id': 803, 'name': 'android'}, {'id': 4270, ...
# 1107   [{'id': 526, 'name': 'rebel'}, {'id': 803, 'na...
# 18068  [{'id': 3230, 'name': 'male friendship'}, {'id...
# 46     [{'id': 476, 'name': 'self-fulfilling prophecy...
# 1178   [{'id': 389, 'name': 'clock tower'}, {'id': 83...
# 512    [{'id': 1382, 'name': 'factory'}, {'id': 1631,...
# 21470  [{'id': 417, 'name': 'corruption'}, {'id': 572...
# 28972  [{'id': 1566, 'name': 'dream'}, {'id': 6513, '...
# 22888  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 17448  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 13381  [{'id': 90, 'name': 'paris'}, {'id': 1008, 'na...
# 23970  [{'id': 237, 'name': 'gay'}, {'id': 392, 'name...
# 17863  [{'id': 849, 'name': 'dc comics'}, {'id': 853,...
# 25544  [{'id': 2095, 'name': 'anti hero'}, {'id': 307...
# 13495  [{'id': 965, 'name': 'age difference'}, {'id':...
# 352    [{'id': 2143, 'name': 'loss of parents'}, {'id...
# 17081  [{'id': 1430, 'name': 'self sacrifice'}, {'id'...
# 5345   [{'id': 616, 'name': 'witch'}, {'id': 970, 'na...
# 22889  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 282    [{'id': 242, 'name': 'new york'}, {'id': 417, ...
# 14566  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 12502          [{'id': 9799, 'name': 'romantic comedy'}]
# 2935   [{'id': 531, 'name': 'southern usa'}, {'id': 5...
# 573    [{'id': 818, 'name': 'based on novel'}, {'id':...
# 23591  [{'id': 380, 'name': 'brother brother relation...
# 3344   [{'id': 588, 'name': 'rome'}, {'id': 1394, 'na...
# 2129   [{'id': 131, 'name': 'italy'}, {'id': 483, 'na...
# 28723  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 14303  [{'id': 1463, 'name': 'culture clash'}, {'id':...
# 22125  [{'id': 612, 'name': 'hotel'}, {'id': 5918, 'n...
# 1131   [{'id': 700, 'name': 'italo-american'}, {'id':...
# 1842   [{'id': 1327, 'name': 'war crimes'}, {'id': 14...
# 3978   [{'id': 30, 'name': 'individual'}, {'id': 328,...
# 25536  [{'id': 803, 'name': 'android'}, {'id': 9831, ...
# 12387  [{'id': 539, 'name': 'middle east'}, {'id': 61...
# 11163  [{'id': 271, 'name': 'competition'}, {'id': 13...
# 1575   [{'id': 2580, 'name': 'shipwreck'}, {'id': 298...
# 7553   [{'id': 334, 'name': 'flying'}, {'id': 2052, '...
# 25534  [{'id': 2964, 'name': 'future'}, {'id': 3713, ...
# 1166   [{'id': 612, 'name': 'hotel'}, {'id': 1533, 'n...
# 9935   [{'id': 486, 'name': 'himalaya'}, {'id': 779, ...
# 1120   [{'id': 526, 'name': 'rebel'}, {'id': 1155, 'n...
# 39340  [{'id': 1416, 'name': 'jazz'}, {'id': 1691, 'n...
# 1019   [{'id': 2052, 'name': 'traitor'}, {'id': 6099,...
# 6238   [{'id': 911, 'name': 'exotic island'}, {'id': ...
# 4636   [{'id': 616, 'name': 'witch'}, {'id': 1441, 'n...

# %%
merged_df = merged_df.head(500)
merged_df.to_json('movies/movies.json', orient='records', indent=2)
